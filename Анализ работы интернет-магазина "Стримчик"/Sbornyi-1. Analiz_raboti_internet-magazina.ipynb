# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Шаг-1.-Загрузка-данных" data-toc-modified-id="Шаг-1.-Загрузка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Шаг 1. Загрузка данных</a></span><ul class="toc-item"><li><span><a href="#Изучим-общую-информацию-о-данных" data-toc-modified-id="Изучим-общую-информацию-о-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Изучим общую информацию о данных</a></span></li></ul></li><li><span><a href="#Шаг-2.-Подготовка-данных" data-toc-modified-id="Шаг-2.-Подготовка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Шаг 2. Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Переименуем-столбцы" data-toc-modified-id="Переименуем-столбцы-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Переименуем столбцы</a></span></li><li><span><a href="#Заполняем-пропуски-и-меняем-типы-данных" data-toc-modified-id="Заполняем-пропуски-и-меняем-типы-данных-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Заполняем пропуски и меняем типы данных</a></span></li><li><span><a href="#Считаем--продажи-по-регионам" data-toc-modified-id="Считаем--продажи-по-регионам-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Считаем  продажи по регионам</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Посчитаем-количество-игр-в-разные-годы" data-toc-modified-id="Посчитаем-количество-игр-в-разные-годы-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Посчитаем количество игр в разные годы</a></span></li><li><span><a href="#Исследуем-продажи-по-платформам" data-toc-modified-id="Исследуем-продажи-по-платформам-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Исследуем продажи по платформам</a></span></li><li><span><a href="#Исследуем--данные-за-актуальный-период-и-рассмотрим-лидирующие-платформы" data-toc-modified-id="Исследуем--данные-за-актуальный-период-и-рассмотрим-лидирующие-платформы-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Исследуем  данные за актуальный период и рассмотрим лидирующие платформы</a></span></li><li><span><a href="#Исследуем-глобальные-продажи-игр-по-платформам" data-toc-modified-id="Исследуем-глобальные-продажи-игр-по-платформам-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Исследуем глобальные продажи игр по платформам</a></span></li><li><span><a href="#Исследуем-влияние-отзывов-критиков-и-пользователей-на-продажи-внутри-платформы-PS4." data-toc-modified-id="Исследуем-влияние-отзывов-критиков-и-пользователей-на-продажи-внутри-платформы-PS4.-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Исследуем влияние отзывов критиков и пользователей на продажи внутри платформы PS4.</a></span></li><li><span><a href="#Исследуем-влияние-отзывов-критиков-и-пользователей-на-продажи-внутри-остальных--платформ" data-toc-modified-id="Исследуем-влияние-отзывов-критиков-и-пользователей-на-продажи-внутри-остальных--платформ-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Исследуем влияние отзывов критиков и пользователей на продажи внутри остальных  платформ</a></span></li><li><span><a href="#Исследуем-общее-распределение-игр-по-жанрам." data-toc-modified-id="Исследуем-общее-распределение-игр-по-жанрам.-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Исследуем общее распределение игр по жанрам.</a></span></li></ul></li><li><span><a href="#Опишем-портрет-пользователя-для-каждого-региона" data-toc-modified-id="Опишем-портрет-пользователя-для-каждого-региона-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Опишем портрет пользователя для каждого региона</a></span><ul class="toc-item"><li><span><a href="#Рассмотрим-самые-популярные-платформы-по-регионам" data-toc-modified-id="Рассмотрим-самые-популярные-платформы-по-регионам-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Рассмотрим самые популярные платформы по регионам</a></span></li><li><span><a href="#Рассмотрим-самые-популярные-жанры-по-регионам" data-toc-modified-id="Рассмотрим-самые-популярные-жанры-по-регионам-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Рассмотрим самые популярные жанры по регионам</a></span></li><li><span><a href="#Исследуем-влияние-рейтинга-ESRB-на-продажи-по-регионам" data-toc-modified-id="Исследуем-влияние-рейтинга-ESRB-на-продажи-по-регионам-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Исследуем влияние рейтинга ESRB на продажи по регионам</a></span></li></ul></li><li><span><a href="#Проверка-гипотез" data-toc-modified-id="Проверка-гипотез-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Проверка гипотез</a></span><ul class="toc-item"><li><span><a href="#Исследуем-пользовательские-рейтинги-платформ-Xbox-One-и-PC" data-toc-modified-id="Исследуем-пользовательские-рейтинги-платформ-Xbox-One-и-PC-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Исследуем пользовательские рейтинги платформ Xbox One и PC</a></span></li><li><span><a href="#Исследуем-пользовательские-рейтинги-жанров-Action-и-Sports" data-toc-modified-id="Исследуем-пользовательские-рейтинги-жанров-Action-и-Sports-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Исследуем пользовательские рейтинги жанров Action и Sports</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Вывод</a></span></li></ul></div>

# %% [markdown]
# <h1>Сборный проект-1. Анализ работы интернет-магазина "Стримчик"<span class="tocSkip"></span></h1>

# %% [markdown]
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».
#
# Описание данных
#
# - Name — название игры
# - Platform — платформа
# - Year_of_Release — год выпуска
# - Genre — жанр игры
# - NA_sales — продажи в Северной Америке (миллионы проданных копий)
# - EU_sales — продажи в Европе (миллионы проданных копий)
# - JP_sales — продажи в Японии (миллионы проданных копий)
# - Other_sales — продажи в других странах (миллионы проданных копий)
# - Critic_Score — оценка критиков (максимум 100)
# - User_Score — оценка пользователей (максимум 10)
# - Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
#
# Данные за 2016 год могут быть неполными.

# %% [markdown]
# </font><font color='Blue'><b>План работы:</b></font><br>
# 1. Загрузим данные и изучим общую информацию
# 2. Предобработаем данные:
# - переименуем столбцы
# - преобразуем типы данных
# - обработаем пропуски
# - посчитаем суммарные продажи во всех регионах и добавим новый столбец
# 3. Проведем исследовательский анализ:
# - сколько игр выпускалось в разные годы
# - как менялись продажи по платформам
# - выберем актуальный период и отфильтруем по нему данные
# - найдем лидирующие по продажам платформы
# - посмотрим как влияют отзывы пользователей и критиков на продажи внутри одной популярной платформы, а затем внутри всех популярных
# - посмотрим на общее распределение игр по жанрам
# 4. Составим портрет пользователя для регионов: NA, EU, JP:
# - найдем top-5 платформ
# - найдем top-5 жанров
# - посмотрим влияет ли рейтинг ESRB на продажи в отдельном регионе
# 5. Проверим гипотезы:
# - равны ли средние пользовательские рейтинги платформ Xbox One и PC
# - равны ли средние пользовательские рейтинги жанров Action и Sports
# 6. Сделаем общий вывод

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats as st

# %% [markdown]
# ## Шаг 1. Загрузка данных

# %%
df = pd.read_csv('/datasets/games.csv')

# %% [markdown]
# ### Изучим общую информацию о данных

# %%
df.head(10)
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#    NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     41.36     28.96      3.77         8.45          76.0          8      E
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
df.shape
# Out:
# (16715, 11)

# %%
print('Период с:', df['Year_of_Release'].min(), 'по', df['Year_of_Release'].max())
# Out:
# Период с: 1980.0 по 2016.0

# %% [markdown]
# Мы загрузили данные из csv-файла, посмотрели основную информацию о типах данных, названиях столбцов. В датафрейме 16715 строк и 11 столбцов. Увидели, что в названиях столбцов нужно исправить регистр, некоторые типы данных на следующем шаге исправим. В датафрейме присутствуют данные с 1980 по 2016 гг.

# %% [markdown]
# ## Шаг 2. Подготовка данных

# %% [markdown]
# ### Переименуем столбцы

# %%
for name in df.columns:
    df = df.rename(columns={name:name.lower()})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# </font><font color='Blue'><b>Проверим наличие явных дубликатов.</b></font><br>

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# </font><font color='Blue'><b>Проверим наличие неявных дубликатов.</b></font><br>

# %%
df.duplicated(subset=['name', 'platform', 'year_of_release'], keep=False).sum()
# Out:
# 4

# %%
df[df.duplicated(subset=['name', 'platform', 'year_of_release'], keep=False)]
# Out:
#                 name platform  year_of_release   genre  na_sales  eu_sales  \
# 604    Madden NFL 13      PS3           2012.0  Sports      2.11      0.22
# 659              NaN      GEN           1993.0     NaN      1.78      0.53
# 14244            NaN      GEN           1993.0     NaN      0.00      0.00
# 16230  Madden NFL 13      PS3           2012.0  Sports      0.00      0.01
#
#        jp_sales  other_sales  critic_score user_score rating
# 604        0.00         0.23          83.0        5.5      E
# 659        0.00         0.08           NaN        NaN    NaN
# 14244      0.03         0.00           NaN        NaN    NaN
# 16230      0.00         0.00          83.0        5.5      E

# %%
df = df.drop_duplicates(subset=['name', 'platform', 'year_of_release'], keep='first')

# %% [markdown]
# Удалили 2 неявных дубликата: оставили строки, где больше заполненных данных.

# %% [markdown]
# ### Заполняем пропуски и меняем типы данных

# %%
round(df.isna().mean()*100,2).reset_index()
# Out:
#               index      0
# 0              name   0.01
# 1          platform   0.00
# 2   year_of_release   1.61
# 3             genre   0.01
# 4          na_sales   0.00
# 5          eu_sales   0.00
# 6          jp_sales   0.00
# 7       other_sales   0.00
# 8      critic_score  51.32
# 9        user_score  40.09
# 10           rating  40.48

# %%
df = df.dropna(subset=['year_of_release'])

# %% [markdown]
# Процент пропусков в столбце 'year_of_release' мал, поэтому можем удалить строки с пропущенными данными в нем.

# %%
df['year_of_release'] = df['year_of_release'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16444 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16443 non-null  object
#  1   platform         16444 non-null  object
#  2   year_of_release  16444 non-null  int64
#  3   genre            16443 non-null  object
#  4   na_sales         16444 non-null  float64
#  5   eu_sales         16444 non-null  float64
#  6   jp_sales         16444 non-null  float64
#  7   other_sales      16444 non-null  float64
#  8   critic_score     7982 non-null   float64
#  9   user_score       9838 non-null   object
#  10  rating           9767 non-null   object
# dtypes: float64(5), int64(1), object(5)
# memory usage: 1.5+ MB

# %%
df.loc[df['name'].isna()]
# Out:
#     name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659  NaN      GEN             1993   NaN      1.78      0.53       0.0
#
#      other_sales  critic_score user_score rating
# 659         0.08           NaN        NaN    NaN

# %%
df = df.dropna(subset=['name'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16443 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16443 non-null  object
#  1   platform         16443 non-null  object
#  2   year_of_release  16443 non-null  int64
#  3   genre            16443 non-null  object
#  4   na_sales         16443 non-null  float64
#  5   eu_sales         16443 non-null  float64
#  6   jp_sales         16443 non-null  float64
#  7   other_sales      16443 non-null  float64
#  8   critic_score     7982 non-null   float64
#  9   user_score       9838 non-null   object
#  10  rating           9767 non-null   object
# dtypes: float64(5), int64(1), object(5)
# memory usage: 1.5+ MB

# %%
df['user_score'].value_counts()
# Out:
# tbd    2376
# 7.8     322
# 8       285
# 8.2     276
# 8.3     252
#        ...
# 0.5       2
# 0.7       2
# 1.9       2
# 0         1
# 9.7       1
# Name: user_score, Length: 96, dtype: int64

# %%
df.loc[df['user_score'] == 'tbd', 'user_score'] = -1

# %%
df['user_score'] = pd.to_numeric(df['user_score'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16443 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16443 non-null  object
#  1   platform         16443 non-null  object
#  2   year_of_release  16443 non-null  int64
#  3   genre            16443 non-null  object
#  4   na_sales         16443 non-null  float64
#  5   eu_sales         16443 non-null  float64
#  6   jp_sales         16443 non-null  float64
#  7   other_sales      16443 non-null  float64
#  8   critic_score     7982 non-null   float64
#  9   user_score       9838 non-null   float64
#  10  rating           9767 non-null   object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.5+ MB

# %%
df['rating'].value_counts()
# Out:
# E       3920
# T       2905
# M       1536
# E10+    1393
# EC         8
# K-A        3
# AO         1
# RP         1
# Name: rating, dtype: int64

# %%
df.loc[df['rating'] == 'K-A', 'rating'] = 'E'
df['rating'].value_counts()
# Out:
# E       3923
# T       2905
# M       1536
# E10+    1393
# EC         8
# AO         1
# RP         1
# Name: rating, dtype: int64

# %%
df['rating'] = df['rating'].fillna('-')

# %%
def type_rating(r):
    if r == 'E':
        return '6+'
    elif r == 'T':
        return '13+'
    elif r == 'M':
        return '17+'
    elif r == 'E10+':
        return '10+'
    elif r == 'EC':
        return '3+'
    elif r == 'RP':
        return 'демо'
    elif r == 'AO':
        return '18+'
    elif r == '-':
        return 'отсутствует'

df['type_rating'] = df['rating'].apply(type_rating)
df
# Out:
#                                 name platform  year_of_release         genre  \
# 0                         Wii Sports      Wii             2006        Sports
# 1                  Super Mario Bros.      NES             1985      Platform
# 2                     Mario Kart Wii      Wii             2008        Racing
# 3                  Wii Sports Resort      Wii             2009        Sports
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16711               LMA Manager 2007     X360             2006        Sports
# 16712        Haitaka no Psychedelica      PSV             2016     Adventure
# 16713               Spirits & Spells      GBA             2003      Platform
# 16714            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %% [markdown]
# ### Считаем  продажи по регионам

# %%
df['total_sales'] = df['na_sales'] + df['eu_sales'] + df['jp_sales'] + df['other_sales']
df
# Out:
#                                 name platform  year_of_release         genre  \
# 0                         Wii Sports      Wii             2006        Sports
# 1                  Super Mario Bros.      NES             1985      Platform
# 2                     Mario Kart Wii      Wii             2008        Racing
# 3                  Wii Sports Resort      Wii             2009        Sports
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16711               LMA Manager 2007     X360             2006        Sports
# 16712        Haitaka no Psychedelica      PSV             2016     Adventure
# 16713               Spirits & Spells      GBA             2003      Platform
# 16714            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %% [markdown]
# Мы изменили регистр во всех названиях столбцов на нижний.
#
# В столбце с годом выпуска релиза пропусков менее 2%, поэтому удалили строки с пропущенными датами и изменили тип данных на 'int', т.к. указана не полная дата, а только год.
#
# Увидели, что в столбце с именем есть 2 пропущенных значения, в этих же строках пропущены практически все значения. Удалим эти 2 строки. Возможно эти пропуски появились при некорректной выгрузке данных.
#
# В столбце 'user_score' тип строка и есть значения 'tbd' (будет определено). Заменили эти значения на '-1' и поменяли тип на 'float'
#
# В интернете нашли расшифровку возрастной категории от организации ESRB:
# - EC - 3+
# - E - 6+
# - E10+ - 10+
# - T - 13+
# - M - 17+
# - AO - 18+
# - RP - демо-версии
# - K-A - 6+ (ранее было К-А, а сейчас Е, поэтому изменили на Е)
#
# и добавили новый столбец с расшифровкой.
#
# Организация ESRB была организована в 1994 году, а данные по играм у нас с 1980 г, поэтому есть пропуски в столбце 'rating'. Заполним эти пропуски '-' и укажем в графе тип рейтинга - 'отсутствует'
#
# Пропуски в столбцах с рейтингами критиков и пользователей заполнять не будем, т.к. у нас нет достоверной информации. Пропуски в рейтингах могут быть связаны с тем, что какие-то игры не так популярны/распространены
#
# Посчитали суммарные продажи по регионам и добавили их в отдельный столбец 'total_sales'.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Посчитаем количество игр в разные годы

# %%
df['year_of_release'].value_counts().sort_index(ascending=True).plot.bar(grid=True, 
                                                                         figsize=(10,7), 
                                                                         rot=45,
                                                                         title='Количество игр по годам')
plt.xlabel('Год')
plt.ylabel('Количество')
plt.show()

# %%
df = df.query('year_of_release >= 1994')

# %% [markdown]
# Мы видим, что наибольшее количество игр было продано в 2008-2009 гг, наименьшее - в 1980. С 1994 г. наблюдается рост продаж. Для дальнейшего анализа будем учитывать данные, начиная с 1994 года.

# %% [markdown]
# ### Исследуем продажи по платформам

# %%
df.pivot_table(index='platform', 
               values='total_sales', 
               aggfunc='sum').sort_values(by='total_sales', 
                                          ascending=False).plot.bar(grid=True, figsize=(10,7), 
                                                                    rot=45, title='Продажи по платформам', legend=False)
plt.xlabel('Платформа')
plt.ylabel('Продажи')
plt.show()

# %% [markdown]
# На графике видим, что самые высокие продажи на платформах 'PS2', 'X360','PS3','Wii', 'DS', 'PS'

# %%
df_pivot_sales = df.pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum')
df_pivot_sales = df_pivot_sales[['PS2', 'X360','PS3','Wii', 'DS', 'PS']]
df_pivot_sales.plot(grid=True, figsize=(10,7), legend=True)
plt.title('Распределение продаж у ТОП-6 платформ по общим продажам')
plt.xlabel('Год')
plt.ylabel('Продажи')
plt.show()

# %%
df_life = df.pivot_table(index='platform', values='year_of_release', aggfunc=['min', 'max']).reset_index()
df_life['life'] = df_life['max'] - df_life['min'] + 1
df_life['life'].median()
# Out:
# 6.0

# %% [markdown]
# Видим, что каждая платформа существует в среднем 6 лет. На пик продаж платформы выходят примерно за 3 года. Значит для построения прогноза на 2017 год, нам нужно взять данные за последние 3 полных года.

# %% [markdown]
# ### Исследуем  данные за актуальный период и рассмотрим лидирующие платформы

# %%
df_actuality = df.query('year_of_release >2012')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16078 entries, 0 to 16714
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16078 non-null  object
#  1   platform         16078 non-null  object
#  2   year_of_release  16078 non-null  int64
#  3   genre            16078 non-null  object
#  4   na_sales         16078 non-null  float64
#  5   eu_sales         16078 non-null  float64
#  6   jp_sales         16078 non-null  float64
#  7   other_sales      16078 non-null  float64
#  8   critic_score     7979 non-null   float64
#  9   user_score       9835 non-null   float64
#  10  rating           16078 non-null  object
#  11  type_rating      16078 non-null  object
#  12  total_sales      16078 non-null  float64
# dtypes: float64(7), int64(1), object(5)
# memory usage: 1.7+ MB

# %%
df_actuality.pivot_table(index='year_of_release', columns='platform', values='total_sales', 
                         aggfunc='sum').plot(grid=True, figsize=(10,7))
plt.legend(bbox_to_anchor=(1.15, 1))
plt.title('Общие продажи по платформам с 2013 г.')
plt.xlabel('Год')
plt.ylabel('Продажи')
plt.show()

# %%
df_actuality.groupby('platform')['total_sales'].sum().sort_values(ascending=False)
# Out:
# platform
# PS4     314.14
# PS3     181.43
# XOne    159.32
# 3DS     143.25
# X360    136.80
# WiiU     64.63
# PC       39.43
# PSV      32.99
# Wii      13.66
# PSP       3.50
# DS        1.54
# Name: total_sales, dtype: float64

# %%
df_actuality.pivot_table(index='year_of_release', 
                         columns='platform', 
                         values='total_sales', 
                         aggfunc='sum').plot.bar(grid=True, rot=30, figsize=(15,7))

plt.legend(bbox_to_anchor=(1.1, 1))
plt.title('Продажи по платформам с 2013 г.')
plt.xlabel('Платформа')
plt.ylabel('Продажи')
plt.show()

# %% [markdown]
# C 2013 лидируют по продажам платформы PS4, PS3, XOne, 3DS, X360. В целом продажи по всем этим платформам прошли свой пик в 2015 г. и затем начали снижаться. Но, вероятно, они будут лидировать на рынке и в 2017 г.

# %%
df_actuality.groupby(['platform', 'year_of_release'])['name'].count().reset_index()
# Out:
#    platform  year_of_release  name
# 0       3DS             2013    91
# 1       3DS             2014    80
# 2       3DS             2015    86
# 3       3DS             2016    46
# 4        DS             2013     8
# 5        PC             2013    38
# 6        PC             2014    47
# 7        PC             2015    50
# 8        PC             2016    54
# 9       PS3             2013   126
# 10      PS3             2014   108
# 11      PS3             2015    73
# 12      PS3             2016    38
# 13      PS4             2013    16
# 14      PS4             2014    75
# 15      PS4             2015   137
# 16      PS4             2016   164
# 17      PSP             2013    54
# 18      PSP             2014    10
# 19      PSP             2015     3
# 20      PSV             2013    63
# 21      PSV             2014   100
# 22      PSV             2015   110
# 23      PSV             2016    85
# 24      Wii             2013    12
# 25      Wii             2014     6
# ...

# %% [markdown]
# Количество выпускаемых игр растет на платфомах PC, PS4, PSV, XOne.
#
# Оставим данные по тем платформам, которые лидируют по продажам и там, где растет количество выпускаемых игр.

# %%
df_actuality_top = df_actuality[df_actuality['platform'].isin(
    ['PS4', 'PS3', 'XOne', '3DS', 'X360', 'PC', 'PSV'])].reset_index(drop=True)

# %%
df_actuality_top['platform'].value_counts()
# Out:
# PS4     392
# PSV     358
# PS3     345
# 3DS     303
# XOne    247
# PC      189
# X360    186
# Name: platform, dtype: int64

# %%
df_actuality_top.head()
# Out:
#                         name platform  year_of_release         genre  \
# 0         Grand Theft Auto V      PS3             2013        Action
# 1         Grand Theft Auto V     X360             2013        Action
# 2  Call of Duty: Black Ops 3      PS4             2015       Shooter
# 3        Pokemon X/Pokemon Y      3DS             2013  Role-Playing
# 4         Grand Theft Auto V      PS4             2014        Action
#
#    na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0      7.02      9.09      0.98         3.96          97.0         8.2      M
# 1      9.66      5.14      0.06         1.41          97.0         8.1      M
# 2      6.03      5.86      0.36         2.38           NaN         NaN      -
# 3      5.28      4.19      4.35         0.78           NaN         NaN      -
# 4      3.96      6.31      0.38         1.97          97.0         8.3      M
#
#    type_rating  total_sales
# 0          17+        21.05
# ...

# %% [markdown]
# ### Исследуем глобальные продажи игр по платформам

# %%
plt.figure(figsize=(10,7))

ax = sns.boxplot(data=df_actuality, x='platform', y='total_sales')
ax.set_title('Распределение продаж игр на платформах')
ax.set_ylabel('Продажи игр, млн.шт.')
ax.set_xlabel('Платформа')

plt.show()

# %%
plt.figure(figsize=(10,7))

ax = sns.boxplot(data=df_actuality, x='platform', y='total_sales')
ax.set_title('Распределение продаж игр на платформах')
ax.set_ylim(0, 2)
ax.set_ylabel('Продажи игр, млн.шт.')
ax.set_xlabel('Платформа')

plt.show()

# %% [markdown]
# Медианные значения продаж смещены к нижнему краю. Это значит, что на всех платформах выходит много игр с относительно небольшими продажами. При этом везде есть бестселлеры, продажи которых могут многократно превышать обычные значения.
#
# Наиболее стабильными по продажам являются следующие платформы: X360, Wii, PS4, XOne, WiU, PS3, т.к. у них шире межквартильный размах.

# %% [markdown]
# ### Исследуем влияние отзывов критиков и пользователей на продажи внутри платформы PS4.

# %%
df_actuality.query('platform == "PS4"')['critic_score'].corr(df_actuality.query('platform == "PS4"')['total_sales']).round(2)
# Out:
# 0.41

# %%
df_actuality.query('platform == "PS4" & user_score != -1')['user_score'].corr(df_actuality.query('platform == "PS4"')
                                                                              ['total_sales']).round(2)
# Out:
# -0.03

# %% [markdown]
# Как видим, корреляция не очень большая. Возможно это по той причине, что продажи не сильно зависят от отзывов. Скорее всего больше зависит от рекламы, уникальности игры.

# %%
fig, axes = plt.subplots(1, 2, figsize=(15,5))
                          
ax=df_actuality.query('platform == "PS4"').plot(ax = axes[0], kind='scatter', x = 'critic_score', y = 'total_sales', 
                                                title = 'Зависимость продаж от оценки критиков')
ax.set_ylabel('Продажи игр, млн.шт.')
ax.set_xlabel('Оценка критиков')

ax=df_actuality.query('platform == "PS4" & user_score != -1').plot(ax = axes[1], kind='scatter', x = 'user_score', 
                                                                   y = 'total_sales', 
                                                                   title = 'Зависимость продаж от оценки пользователей')
ax.set_ylabel('Продажи игр, млн.шт.')
ax.set_xlabel('Оценка пользователей')

plt.suptitle('Продажи внутри платформы PS4')
plt.show()

# %% [markdown]
# Самые продаваемые игры имеют оценки пользователей от 5,5 и оценки критиков от 60.

# %% [markdown]
# ### Исследуем влияние отзывов критиков и пользователей на продажи внутри остальных  платформ

# %%
for pl in df_actuality['platform'].unique():
       
    cor = df_actuality.loc[df_actuality.platform == pl]['critic_score'].corr(df_actuality.loc
                                                                             [df_actuality.platform == pl]['total_sales'])
    print('Корреляция на платформе', pl, 'между оценкой критиков и общими продами =', cor)
    
    cor_p = df_actuality.loc[(df_actuality.platform == pl) & (df_actuality.user_score != -1)]['user_score'].corr(
        df_actuality.loc[(df_actuality.platform == pl) & (df_actuality.user_score != -1)]['total_sales'])
    print('Корреляция на платформе', pl, 'между оценкой пользователей и общими продами =', cor_p)
    print()

        
    fig, axes = plt.subplots(1, 2, figsize=(15,5))
    ax=df_actuality.loc[df_actuality.platform == pl].plot(ax = axes[0], kind='scatter', x = 'critic_score', 
                                                           y = 'total_sales', title = 'Зависимость продаж от оценки критиков')
    ax.set_ylabel('Продажи игр, млн.шт.')
    ax.set_xlabel('Оценка критиков')

    ax=df_actuality.loc[(df_actuality.platform == pl) & (df_actuality.user_score != -1)].plot(ax = axes[1], kind='scatter', x = 'user_score', 
                                                           y = 'total_sales', title = 'Зависимость продаж от оценки пользователей')
    ax.set_ylabel('Продажи игр, млн.шт.')
    ax.set_xlabel('Оценка пользователей')
    plt.suptitle('Продажи внутри платформы' + pl) 
    plt.show()
# Out:
# Корреляция на платформе PS3 между оценкой критиков и общими продами = 0.3342853393371919
# Корреляция на платформе PS3 между оценкой пользователей и общими продами = 0.0023944027357566925
# Корреляция на платформе X360 между оценкой критиков и общими продами = 0.3503445460228664
# Корреляция на платформе X360 между оценкой пользователей и общими продами = -0.011742185147181342
# Корреляция на платформе PS4 между оценкой критиков и общими продами = 0.40656790206178095
# Корреляция на платформе PS4 между оценкой пользователей и общими продами = -0.031957110204556376
# Корреляция на платформе 3DS между оценкой критиков и общими продами = 0.3570566142288103
# Корреляция на платформе 3DS между оценкой пользователей и общими продами = 0.24150411773563016
# Корреляция на платформе XOne между оценкой критиков и общими продами = 0.4169983280084017
# Корреляция на платформе XOne между оценкой пользователей и общими продами = -0.06892505328279414
# ...

# %% [markdown]
# Как видим, зависимость продаж от оценок критиков и пользователей в среднем не сильно отличается. Значит, оценки не сильно влияют на объемы продаж.

# %% [markdown]
# ### Исследуем общее распределение игр по жанрам.

# %%
df_actuality.pivot_table(index='genre', 
                         values='total_sales', 
                         aggfunc='sum').sort_values(by='total_sales', 
                                                    ascending=False).plot.bar(grid=True, 
                                                                              figsize=(10,7), 
                                                                              title='Продажи по жанрам', 
                                                                              legend=False, 
                                                                              rot=30)
plt.xlabel('Жанры')
plt.ylabel('Продажи')
plt.show()

# %%
df_actuality.groupby('genre')['total_sales'].sum().reset_index().sort_values(by = 'total_sales', ascending = False)
# Out:
#            genre  total_sales
# 0         Action       321.87
# 8        Shooter       232.98
# 10        Sports       150.65
# 7   Role-Playing       145.89
# 3           Misc        62.82
# 4       Platform        42.63
# 6         Racing        39.89
# 2       Fighting        35.31
# 1      Adventure        23.64
# 9     Simulation        21.76
# 11      Strategy        10.08
# 5         Puzzle         3.17

# %%
df_actuality_genre = df_actuality.pivot_table(index='genre', columns='platform', values='total_sales', aggfunc='sum')
df_actuality_genre['mean_sales'] = df_actuality_genre.median(axis=1)
df_actuality_genre.sort_values(by='mean_sales', ascending=False)
# Out:
# platform        3DS    DS    PC    PS3    PS4   PSP    PSV   Wii   WiiU  \
# genre
# Shooter        0.06   NaN  9.84  31.79  88.56   NaN   1.44   NaN   5.48
# Action        34.04  0.50  7.26  70.92  96.10  0.86   9.72  2.82  14.75
# Role-Playing  67.37   NaN  4.87  16.49  28.99  1.03  10.23   NaN   1.93
# Misc           7.10  0.08  0.71   8.36   8.19  0.17   3.85  7.06   7.38
# Racing          NaN   NaN  0.97   6.46  12.14   NaN   0.10   NaN   7.36
# Fighting       8.21   NaN  0.10   6.05   8.65  0.02   1.19   NaN   6.09
# Platform       8.79  0.69  0.07   3.33   7.69   NaN   0.47  2.25  16.27
# Sports         1.82  0.03  1.96  32.35  55.61  0.69   2.08  0.95   2.46
# Adventure      3.33  0.03  0.51   4.32   6.34  0.71   3.45  0.18   0.17
# Simulation     9.53  0.21  8.11   0.71   1.23   NaN   0.05  0.14   0.20
# Strategy       1.27   NaN  5.03   0.61   0.62  0.02   0.35  0.26   1.22
# Puzzle         1.73   NaN   NaN   0.04   0.02   NaN   0.06   NaN   1.32
#
# ...

# %%
plt.figure(figsize=(10,7))

ax = sns.boxplot(data=df_actuality, x='genre', y='total_sales')
ax.set_title('Распределение продаж игр на платформах')
ax.set_ylabel('Продажи игр, млн.шт.')
ax.set_xlabel('Платформа')

plt.show()

# %%
plt.figure(figsize=(10,7))

ax = sns.boxplot(data=df_actuality, x='genre', y='total_sales')
ax.set_title('Распределение продаж игр на платформах')
ax.set_ylim(0, 5)
ax.set_ylabel('Продажи игр, млн.шт.')
ax.set_xlabel('Платформа')

plt.show()

# %% [markdown]
# Самые прибыльный жанр по средним продажам - это Shooter.

# %% [markdown]
# ## Опишем портрет пользователя для каждого региона

# %% [markdown]
# ### Рассмотрим самые популярные платформы по регионам

# %%
df_actuality_platform = df_actuality.pivot_table(index='platform', 
                                                values = ['na_sales', 'eu_sales', 'jp_sales'], 
                                                aggfunc = 'sum')
df_actuality_platform
# Out:
#           eu_sales  jp_sales  na_sales
# platform
# 3DS          30.96     67.81     38.20
# DS            0.85      0.00      0.57
# PC           25.36      0.00     11.11
# PS3          67.81     23.35     63.50
# PS4         141.09     15.96    108.74
# PSP           0.17      3.29      0.00
# PSV           6.10     18.59      5.04
# Wii           5.93      0.05      6.56
# WiiU         19.85     10.88     29.21
# X360         42.52      0.51     81.66
# XOne         51.59      0.34     93.12

# %%
fig, axes = plt.subplots(1, 3, figsize=(15,15))

ax=df_actuality_platform['na_sales'].sort_values(ascending=False).plot(ax = axes[0], kind='pie',
                                                                   figsize=(15, 5),
                                                                   autopct='%1.1f%%',
                                                                   pctdistance=0.8,
                                                                   cmap='rainbow',
                                                                   title='Северная Америка')
ax.set_ylabel('')


ax=df_actuality_platform['eu_sales'].sort_values(ascending=False).plot(ax = axes[1], kind='pie',
                                                                   figsize=(15, 5),
                                                                   autopct='%1.1f%%',
                                                                   pctdistance=0.8,
                                                                   cmap='rainbow',
                                                                   title='Европа')
ax.set_ylabel('')

ax=df_actuality_platform['jp_sales'].sort_values(ascending=False).plot(ax = axes[2], kind='pie',
                                                                   figsize=(15, 5),
                                                                   autopct='%1.1f%%',
                                                                   pctdistance=0.8,
                                                                   cmap='rainbow',
                                                                   title='Япония')
ax.set_ylabel('')

plt.suptitle('Доли продаж по платформам по регионам')
plt.show()

# %%
df_pl_na = (df_actuality_platform['na_sales'].sort_values(ascending=False))[0:5].reset_index()
res1 = (df_actuality_platform['na_sales'].sort_values(ascending=False))[5:].sum(axis=0)
df_pl_na.loc[len(df_pl_na)] = ['Other', res1]
df_pl_na.set_index('platform', inplace=True)

# %%
df_pl_na['na_sales'].sort_values(ascending=False).plot(kind='pie', y='na_sales', figsize=(5, 5), autopct='%1.1f%%', 
                                                    pctdistance=0.8, title='Северная Америка')
plt.ylabel('')
plt.show()

# %%
df_pl_eu = (df_actuality_platform['eu_sales'].sort_values(ascending=False))[0:5].reset_index()
res2 = (df_actuality_platform['eu_sales'].sort_values(ascending=False))[5:].sum(axis=0)
df_pl_eu.loc[len(df_pl_eu)] = ['Other', res2]
df_pl_eu.set_index('platform', inplace=True)

# %%
df_pl_eu['eu_sales'].sort_values(ascending=False).plot(kind='pie', y='eu_sales', figsize=(5, 5), autopct='%1.1f%%', 
                                                    pctdistance=0.8, title='Европа')
plt.ylabel('')
plt.show()

# %%
df_pl_jp = (df_actuality_platform['jp_sales'].sort_values(ascending=False))[0:5].reset_index()
res3 = (df_actuality_platform['jp_sales'].sort_values(ascending=False))[5:].sum(axis=0)
df_pl_jp.loc[len(df_pl_jp)] = ['Other', res3]
df_pl_jp.set_index('platform', inplace=True)

# %%
df_pl_jp['jp_sales'].sort_values(ascending=False).plot(kind='pie', y='jp_sales', figsize=(5, 5), autopct='%1.1f%%', 
                                                    pctdistance=0.8, title='Япония')
plt.ylabel('')
plt.show()

# %% [markdown]
# Как видим, топ-5 платформ по регионам отличается, особенно с Японией. Но в то же время, PS3 во всех регионах занимает практически лидирующую позицию.

# %% [markdown]
# ### Рассмотрим самые популярные жанры по регионам

# %%
df_actuality_genre = df_actuality.pivot_table(index='genre', 
                                                values = ['na_sales', 'eu_sales', 'jp_sales'], 
                                                aggfunc = 'sum')
df_actuality_genre
# Out:
#               eu_sales  jp_sales  na_sales
# genre
# Action          118.13     40.49    126.05
# Adventure         8.25      5.82      7.14
# Fighting          8.55      7.65     15.55
# Misc             20.04      9.20     27.49
# Platform         15.58      4.79     18.14
# Puzzle            1.00      1.18      0.83
# Racing           20.19      2.30     12.96
# Role-Playing     36.97     51.04     46.40
# Shooter          87.86      6.61    109.74
# Simulation       10.92      4.52      4.86
# Sports           60.52      5.41     65.27
# Strategy          4.22      1.77      3.28

# %%
fig, axes = plt.subplots(1, 3, figsize=(15,15))

ax=df_actuality_genre['na_sales'].sort_values(ascending=False).plot(ax = axes[0], kind='pie',
                                                                   figsize=(15, 5),
                                                                   autopct='%1.1f%%',
                                                                   pctdistance=0.8,
                                                                   cmap='rainbow',
                                                                   title='Северная Америка')
ax.set_ylabel('')

ax=df_actuality_genre['eu_sales'].sort_values(ascending=False).plot(ax = axes[1], kind='pie',
                                                                   figsize=(15, 5),
                                                                   autopct='%1.1f%%',
                                                                   pctdistance=0.8,
                                                                   cmap='rainbow',
                                                                   title='Европа')
ax.set_ylabel('')

ax=df_actuality_genre['jp_sales'].sort_values(ascending=False).plot(ax = axes[2], kind='pie',
                                                                   figsize=(15, 5),
                                                                   autopct='%1.1f%%',
                                                                   pctdistance=0.8,
                                                                   cmap='rainbow',
                                                                   title='Япония')
ax.set_ylabel('')

plt.suptitle('Доли продаж по жанрам по регионам')
plt.show()

# %%
df_genre_na = (df_actuality_genre['na_sales'].sort_values(ascending=False))[0:5].reset_index()
res1 = (df_actuality_genre['na_sales'].sort_values(ascending=False))[5:].sum(axis=0)
df_genre_na.loc[len(df_genre_na)] = ['Other', res1]
df_genre_na.set_index('genre', inplace=True)

# %%
df_genre_na['na_sales'].sort_values(ascending=False).plot(kind='pie', y='na_sales', figsize=(5, 5), autopct='%1.1f%%', 
                                                    pctdistance=0.8, title='Северная Америка')
plt.ylabel('')
plt.show()

# %%
df_genre_eu = (df_actuality_genre['eu_sales'].sort_values(ascending=False))[0:5].reset_index()
res2 = (df_actuality_genre['eu_sales'].sort_values(ascending=False))[5:].sum(axis=0)
df_genre_eu.loc[len(df_genre_eu)] = ['Other', res2]
df_genre_eu.set_index('genre', inplace=True)

# %%
df_genre_eu['eu_sales'].sort_values(ascending=False).plot(kind='pie', y='eu_sales', figsize=(5, 5), autopct='%1.1f%%', 
                                                    pctdistance=0.8, title='Европа')
plt.ylabel('')
plt.show()

# %%
df_genre_jp = (df_actuality_genre['jp_sales'].sort_values(ascending=False))[0:5].reset_index()
res3 = (df_actuality_genre['jp_sales'].sort_values(ascending=False))[5:].sum(axis=0)
df_genre_jp.loc[len(df_genre_jp)] = ['Other', res3]
df_genre_jp.set_index('genre', inplace=True)

# %%
df_genre_jp['jp_sales'].sort_values(ascending=False).plot(kind='pie', y='jp_sales', figsize=(5, 5), autopct='%1.1f%%', 
                                                    pctdistance=0.8, title='Европа')
plt.ylabel('')
plt.show()

# %% [markdown]
# Как видим, топ-5 жанров в Северной Америке и Европе похож, сходится рейтинг 4-х жанров: самые популярные здесь Action, Shooter, Sports. Япония же сильно отличается своими предпочтениями: здесь лидирующую позицию занимает Role-Playing. Однако, во всех регионах Action занимает практически лидирующую позицию.

# %% [markdown]
# ### Исследуем влияние рейтинга ESRB на продажи по регионам

# %%
df_actuality_rating = df_actuality.pivot_table(index='type_rating', 
                                               values=['na_sales', 'eu_sales', 'jp_sales'], 
                                               aggfunc='sum')
df_actuality_rating
# Out:
#              eu_sales  jp_sales  na_sales
# type_rating
# 10+             42.69      5.89     54.24
# 13+             41.95     20.59     49.79
# 17+            145.32     14.11    165.21
# 6+              83.36     15.14     79.05
# отсутствует     78.91     85.05     89.42

# %% [markdown]
# В Северной Америке и Европе самые популярные - это игры для взрослых 17+ и категория 6+, а в Японии - многие игры не имеют категории, а из известных - основную долю занимают игры из категории 6+ и 13+.

# %% [markdown]
# ## Проверка гипотез

# %% [markdown]
# ### Исследуем пользовательские рейтинги платформ Xbox One и PC

# %% [markdown]
# Нулевая гипотеза: средние пользовательские рейтинги платформ XOne и PC равны.
#
# Альтернативная гипотеза: средние пользовательские рейтинги платформ XOne и PC не равны.

# %%
df_actuality.query('platform in ["XOne", "PC"]').dropna(subset=['user_score']).pivot_table(index='platform', values='user_score')
# Out:
#           user_score
# platform
# PC          6.042500
# XOne        6.092746

# %%
x_one = df_actuality.query('platform == "XOne" & user_score != -1').dropna(subset=['user_score'])
pc = df_actuality.query('platform == "PC" & user_score != -1').dropna(subset=['user_score'])

# %%
alpha = 0.05
result = st.ttest_ind(x_one['user_score'], pc['user_score'], equal_var=False)
print('p-значение:', result.pvalue)
if (result.pvalue < alpha):
    print('Отклоняем нулевую гипотезу')
else:
    print('Не отклоняем нулевую гипотезу')
# Out:
# p-значение: 0.14759594013430463
# Не отклоняем нулевую гипотезу

# %% [markdown]
# Мы предположили, что средние пользвательские рейтинги платформ XOne и PC равны. Проверили гипотезу о равенстве средних двух генеральных совокупностей.
#
# Для этого посчитали p-value, используя ttest из библиотеки scipy для сравнения средних двух выборок. Использовали параметр equal_var=False, т.к. есть сомнения в равенстве дисперсий наших выборок.
#
# Т.к. p-value больше выбранного уровня значимости, то нулевую гипотезу о равенстве средних мы не можем отвергнуть. Т.е. мы не можем утверждать, что средние пользовательские рейтинги платформ XOne и PC не равны.

# %% [markdown]
# ### Исследуем пользовательские рейтинги жанров Action и Sports

# %% [markdown]
# Нулевая гипотеза: средние пользовательские рейтинги жанров Action и Sports равны.
#
# Альтернативная гипотеза: средние пользовательские рейтинги жанров Action и Sports не равны.

# %%
df_actuality.query('genre in ["Action", "Sports"]').dropna(subset=['user_score']).pivot_table(index='genre', values='user_score')
# Out:
#         user_score
# genre
# Action    6.057407
# Sports    4.769364

# %%
action = df_actuality.query('genre == "Action" & user_score != -1').dropna(subset=['user_score'])
sports = df_actuality.query('genre == "Sports" & user_score != -1').dropna(subset=['user_score'])

# %%
alpha = 0.05
result = st.ttest_ind(action['user_score'], sports['user_score'], equal_var=False)
print('p-значение:', result.pvalue)
if (result.pvalue < alpha):
    print('Отклоняем нулевую гипотезу')
else:
    print('Не отклоняем нулевую гипотезу')
# Out:
# p-значение: 1.4460039700704315e-20
# Отклоняем нулевую гипотезу

# %% [markdown]
# Мы предположили, что средние пользвательские рейтинги жанров Action и Sports не отличаются. Проверили гипотезу о равенстве средних двух генеральных совокупностей.
#
# Для этого посчитали p-value, используя ttest из библиотеки scipy для сравнения средних двух выборок. Использовали параметр equal_var=False, т.к. есть сомнения в равенстве дисперсий наших выборок.
#
# Т.к. p-value меньше выбранного уровня значимости, то нулевую гипотезу о равенстве средних отвергаем. Т.е. мы можем сказать, что средние пользовательские рейтинги жанров Action и Sports могут отличаться.

# %% [markdown]
# ## Вывод

# %% [markdown]
# В ходе исследования на основе загруженных данных мы сделали следующие выводы:
#
# - наибольшее количество игр было продано в 2008-2009 гг, наименьшее - в 1980. С 1994 г. наблюдается рост продаж.
#
# - каждая платформа существует в среднем 6 лет. На пик продаж платформы выходят примерно за 3 года. Для построения прогноза на 2017 год, мы берем данные с 2013 года.
#
# - с 2013 лидируют по продажам платформы PS3, X360, PS4, 3DS, XOne. В целом продажи по всем этим платформам прошли свой пик в 20015 г. и начали снижаться. Но, вероятно, они будут лидировать на рынке и в 2017 г.
#
# - количество выпускаемых игр растет на платфомах PC, PS4, PSV, XOne. Таким образом, для прогноза на 2017 г. оставим данные по тем платформам, которые лидируют по продажам и там, где растет количество выпускаемых игр.
#
# - корреляция между оценками критиков\пользователей и продажами не очень большая, что говорит о том, что продажи не сильно зависят от отзывов. Скорее всего больше зависят от рекламы, уникальности игры.
#
# - самые популярные жанры - это Action, Shooter, Role-Playing, а меньше всего - Strategy и Puzzle. Самые прибыльный жанр по средним продажам - это Shooter.
#
# - если делить по рынкам, то самые популярные платформы:
#      * в Америке : X360, PS3, PS4
#      * в Европе - PS3, PS4, X360
#      * а вот Япония отличается: 3DS, PS3, PSP
#
# - самые популярные жанры:
#     * Америка и Европа схожа по предпочтениям: Action, Shooter, Sports
#     * Япония отличается и здесь: Role-Playing, Action, Misc
#
# - В Северной Америке и Европе самые популярные - это игры для взрослых 17+ и категория 6+, а в Японии - многие игры не имеют категории, а из известных - основную долю занимают игры из категории 6+ и 13+.
#
# В ходе исследования были проверены две гипотезы: о равенстве средних пользовательских рейтингов игр на платформах XOne и PC, и жанров Action и Sports. Мы не можем утверждать, что средние пользовательские рейтинги платформ XOne и PC не равны.  А что  средние пользовательские рейтинги жанров Action и Sports могут отличаться мы доказали.
#
# <b> ИТАК: </b>
#
# В последние годы лидерство на рынке принадлежит Sony PlayStation (PS4, PS3) и Xbox One (XOne) от Microsoft. На них выпускается больше всего игр, больше всего громких новинок, и на них приходятся самые высокие продажи. Если делить по рынкам, то в Америке и Европе наиболее популярны игры платформы PS4, а в Японии - 3DS. По жанрам в Америке и Европе популярны Action, Shooter, в Японии - Role-Playing. Целевая аудитория Америки и Европы - это 17+, в Японии - 13+.
